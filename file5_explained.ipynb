# %% [markdown]
# # Explicação passo-a-passo do notebook `file5.ipynb`
#
# Este notebook foi gerado automaticamente para explicar **linha a linha** e **bloco por bloco** o conteúdo do arquivo original.
# Cada célula de código original é repetida e seguida por uma célula de *Markdown* que contém:
# - explicação linha a linha (em termos simples),
# - quais parâmetros/valores influenciam o comportamento,
# - conceitos e técnicas usados nessa célula,
# - observações/alertas quando aplicáveis.
#
# **Aviso:** explicações automáticas são aproximações estáticas — pode haver detalhes de tempo de execução que exigem inspeção manual. Se desejar, posso ajustar a explicação para focar em partes específicas.

# %% [markdown]
# **(Célula Markdown original)**
#
# # PLN com Embedding em VectorDB

# %%
# Bibliotecas para PLN 

 

# Para chunks e embeddings 

from langchain_text_splitters import RecursiveCharacterTextSplitter # pip install langchain-text-splitters

from sentence_transformers import SentenceTransformer # pip install sentence_transformers 

 

# Para leitura de PDF 

import pdfplumber # pip install pdfplumber 

 

# Para tratamento de texto 

import re 

import spacy # python -m spacy download pt_core_news_sm 

import nltk # pip install nltk 

from nltk.corpus import stopwords 

# Baixando dados do NLTK necessários (se ainda não tiver) 

nltk.download('stopwords') # rodar apenas uma vez

# %% [markdown]
# ### Célula 2 — Explicação detalhada
#
# **Código original:**
# ```python
# # Bibliotecas para PLN
#
#
#
# # Para chunks e embeddings
#
# from langchain_text_splitters import RecursiveCharacterTextSplitter # pip install langchain-text-splitters
#
# from sentence_transformers import SentenceTransformer # pip install sentence_transformers
#
#
#
# # Para leitura de PDF
#
# import pdfplumber # pip install pdfplumber
#
#
#
# # Para tratamento de texto
#
# import re
#
# import spacy # python -m spacy download pt_core_news_sm
#
# import nltk # pip install nltk
#
# from nltk.corpus import stopwords
#
# # Baixando dados do NLTK necessários (se ainda não tiver)
#
# nltk.download('stopwords') # rodar apenas uma vez
# ```
#
# **Explicação linha-a-linha:**
#
# - **Linha 1:** `# Bibliotecas para PLN `
#   - Tipo: comment
#   - Explicação: Comment: Bibliotecas para PLN — explains intent or documents nearby code.
# - **Linha 2:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 3:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 4:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 5:** `# Para chunks e embeddings `
#   - Tipo: comment
#   - Explicação: Comment: Para chunks e embeddings — explains intent or documents nearby code.
# - **Linha 6:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 7:** `from langchain_text_splitters import RecursiveCharacterTextSplitter # pip install langchain-text-splitters`
#   - Tipo: import
#   - Explicação: Imports RecursiveCharacterTextSplitter. These modules provide external functionality; removing them may break code that depends on them.
# - **Linha 8:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 9:** `from sentence_transformers import SentenceTransformer # pip install sentence_transformers `
#   - Tipo: import
#   - Explicação: Imports SentenceTransformer. These modules provide external functionality; removing them may break code that depends on them.
# - **Linha 10:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 11:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 12:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 13:** `# Para leitura de PDF `
#   - Tipo: comment
#   - Explicação: Comment: Para leitura de PDF — explains intent or documents nearby code.
# - **Linha 14:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 15:** `import pdfplumber # pip install pdfplumber `
#   - Tipo: import
#   - Explicação: Imports pdfplumber. These modules provide external functionality; removing them may break code that depends on them.
# - **Linha 16:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 17:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 18:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 19:** `# Para tratamento de texto `
#   - Tipo: comment
#   - Explicação: Comment: Para tratamento de texto — explains intent or documents nearby code.
# - **Linha 20:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 21:** `import re `
#   - Tipo: import
#   - Explicação: Imports re. These modules provide external functionality; removing them may break code that depends on them.
# - **Linha 22:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 23:** `import spacy # python -m spacy download pt_core_news_sm `
#   - Tipo: import
#   - Explicação: Imports spacy. These modules provide external functionality; removing them may break code that depends on them.
# - **Linha 24:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 25:** `import nltk # pip install nltk `
#   - Tipo: import
#   - Explicação: Imports nltk. These modules provide external functionality; removing them may break code that depends on them.
# - **Linha 26:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 27:** `from nltk.corpus import stopwords `
#   - Tipo: import
#   - Explicação: Imports stopwords. These modules provide external functionality; removing them may break code that depends on them.
# - **Linha 28:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 29:** `# Baixando dados do NLTK necessários (se ainda não tiver) `
#   - Tipo: comment
#   - Explicação: Comment: Baixando dados do NLTK necessários (se ainda não tiver) — explains intent or documents nearby code.
# - **Linha 30:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 31:** `nltk.download(&#x27;stopwords&#x27;) # rodar apenas uma vez `
#   - Tipo: function_call
#   - Explicação: Function call: nltk.download(...). Arguments determine what the function does.
#
# **Conceitos / técnicas usados nesta célula:**
# - general Python logic (variables, control flow, function calls)
#
# **Observações gerais:**
# - Parâmetros literais e constantes (ex.: números, strings) geralmente controlam comportamento e são fáceis de ajustar.
# - Chamadas de função podem encapsular lógica complexa — revisar definição da função (se estiver neste notebook) para entender o efeito total.
# - Se a célula importa bibliotecas, essas bibliotecas devem estar instaladas no ambiente para executar o código.
#
# ---

# %% [markdown]
# **(Célula Markdown original)**
#
# # Bibliotecas para Banco de Dados Vetorial (Vector Database)

# %%
import chromadb 

from langchain_chroma import Chroma

# %% [markdown]
# ### Célula 4 — Explicação detalhada
#
# **Código original:**
# ```python
# import chromadb
#
# from langchain_chroma import Chroma
# ```
#
# **Explicação linha-a-linha:**
#
# - **Linha 1:** `import chromadb `
#   - Tipo: import
#   - Explicação: Imports chromadb. These modules provide external functionality; removing them may break code that depends on them.
# - **Linha 2:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 3:** `from langchain_chroma import Chroma `
#   - Tipo: import
#   - Explicação: Imports Chroma. These modules provide external functionality; removing them may break code that depends on them.
#
# **Conceitos / técnicas usados nesta célula:**
# - general Python logic (variables, control flow, function calls)
#
# **Observações gerais:**
# - Parâmetros literais e constantes (ex.: números, strings) geralmente controlam comportamento e são fáceis de ajustar.
# - Chamadas de função podem encapsular lógica complexa — revisar definição da função (se estiver neste notebook) para entender o efeito total.
# - Se a célula importa bibliotecas, essas bibliotecas devem estar instaladas no ambiente para executar o código.
#
# ---

# %% [markdown]
# **(Célula Markdown original)**
#
# # Aplicando PLN - Preparação do texto

# %%
# Carregando PDFs 

 

def ler_pdf(caminho_pdf):
    leitor_pdf = pdfplumber.open(caminho_pdf) 

# page = leitor_pdf.pages[0]
    texto = "" 

    for pagina in range(len(leitor_pdf.pages)):
        texto += leitor_pdf.pages[pagina].extract_text()
    texto = texto.replace("\n", " ") 

    return texto 

 

 

# Carregar os documentos do PDF 

arquivo_pdf = "/Users/ALEKS/Downloads/ML/introducaoml.pdf" 

texto_pdf = ler_pdf(arquivo_pdf) 

 

# Tamanho do texto 

print("Tamanho do texto em caracteres:",len(texto_pdf)) 


# Arquivo PDF original 

print(texto_pdf) 


# PLN 

# Carregar o modelo de linguagem do spaCy 

nlp = spacy.load("pt_core_news_sm") # Definir stopwords 

api_stop_words = set(stopwords.words('portuguese')) 

minhas_stop_words = {'a','e','i','o', 'u'} 

stop_words = api_stop_words | minhas_stop_words

# %% [markdown]
# ### Célula 6 — Explicação detalhada
#
# **Código original:**
# ```python
# # Carregando PDFs
#
#
#
# def ler_pdf(caminho_pdf):
#     leitor_pdf = pdfplumber.open(caminho_pdf)
#
# # page = leitor_pdf.pages[0]
#     texto = ""
#
#     for pagina in range(len(leitor_pdf.pages)):
#         texto += leitor_pdf.pages[pagina].extract_text()
#     texto = texto.replace("\n", " ")
#
#     return texto
#
#
#
#
#
# # Carregar os documentos do PDF
#
# arquivo_pdf = "/Users/ALEKS/Downloads/ML/introducaoml.pdf"
#
# texto_pdf = ler_pdf(arquivo_pdf)
#
#
#
# # Tamanho do texto
#
# print("Tamanho do texto em caracteres:",len(texto_pdf))
#
#
# # Arquivo PDF original
#
# print(texto_pdf)
#
#
# # PLN
#
# # Carregar o modelo de linguagem do spaCy
#
# nlp = spacy.load("pt_core_news_sm") # Definir stopwords
#
# api_stop_words = set(stopwords.words('portuguese'))
#
# minhas_stop_words = {'a','e','i','o', 'u'}
#
# stop_words = api_stop_words | minhas_stop_words
#
#
# ```
#
# **Explicação linha-a-linha:**
#
# - **Linha 1:** `# Carregando PDFs `
#   - Tipo: comment
#   - Explicação: Comment: Carregando PDFs — explains intent or documents nearby code.
# - **Linha 2:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 3:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 4:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 5:** `def ler_pdf(caminho_pdf):`
#   - Tipo: function_def
#   - Explicação: Function definition: defines a callable block. Parameters in parentheses influence behavior when function is called.
# - **Linha 6:** `    leitor_pdf = pdfplumber.open(caminho_pdf) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to leitor_pdf from function 'pdfplumber.open()'. Changing function arguments will change the assigned value.
# - **Linha 7:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 8:** `# page = leitor_pdf.pages[0]`
#   - Tipo: comment
#   - Explicação: Comment: page = leitor_pdf.pages[0] — explains intent or documents nearby code.
# - **Linha 9:** `    texto = &quot;&quot; `
#   - Tipo: assignment_const
#   - Explicação: Assigns constant value ('') to texto. Changing this literal value will directly affect behavior/configuration.
# - **Linha 10:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 11:** `    for pagina in range(len(leitor_pdf.pages)):`
#   - Tipo: unknown
#   - Explicação: Could not statically parse this line; it's: for pagina in range(len(leitor_pdf.pages)):
# - **Linha 12:** `        texto += leitor_pdf.pages[pagina].extract_text()`
#   - Tipo: other
#   - Explicação: Other AST node type: AugAssign. This line performs an operation that may be complex; manual review recommended.
# - **Linha 13:** `    texto = texto.replace(&quot;\n&quot;, &quot; &quot;) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to texto from function 'texto.replace()'. Changing function arguments will change the assigned value.
# - **Linha 14:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 15:** `    return texto `
#   - Tipo: return
#   - Explicação: Return statement: returns a value from a function. Changing it changes what callers receive.
# - **Linha 16:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 17:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 18:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 19:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 20:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 21:** `# Carregar os documentos do PDF `
#   - Tipo: comment
#   - Explicação: Comment: Carregar os documentos do PDF — explains intent or documents nearby code.
# - **Linha 22:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 23:** `arquivo_pdf = &quot;/Users/ALEKS/Downloads/ML/introducaoml.pdf&quot; `
#   - Tipo: assignment_const
#   - Explicação: Assigns constant value ('/Users/ALEKS/Downloads/ML/introducaoml.pdf') to arquivo_pdf. Changing this literal value will directly affect behavior/configuration. Alterar este valor ('/Users/ALEKS/Downloads/ML/introducaoml.pdf') muda diretamente o comportamento/configuração que depende desta variável.
# - **Linha 24:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 25:** `texto_pdf = ler_pdf(arquivo_pdf) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to texto_pdf from function 'ler_pdf()'. Changing function arguments will change the assigned value.
# - **Linha 26:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 27:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 28:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 29:** `# Tamanho do texto `
#   - Tipo: comment
#   - Explicação: Comment: Tamanho do texto — explains intent or documents nearby code.
# - **Linha 30:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 31:** `print(&quot;Tamanho do texto em caracteres:&quot;,len(texto_pdf)) `
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
# - **Linha 32:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 33:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 34:** `# Arquivo PDF original `
#   - Tipo: comment
#   - Explicação: Comment: Arquivo PDF original — explains intent or documents nearby code.
# - **Linha 35:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 36:** `print(texto_pdf) `
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
# - **Linha 37:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 38:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 39:** `# PLN `
#   - Tipo: comment
#   - Explicação: Comment: PLN — explains intent or documents nearby code.
# - **Linha 40:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 41:** `# Carregar o modelo de linguagem do spaCy `
#   - Tipo: comment
#   - Explicação: Comment: Carregar o modelo de linguagem do spaCy — explains intent or documents nearby code.
# - **Linha 42:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 43:** `nlp = spacy.load(&quot;pt_core_news_sm&quot;) # Definir stopwords `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to nlp from function 'spacy.load()'. Changing function arguments will change the assigned value.
# - **Linha 44:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 45:** `api_stop_words = set(stopwords.words(&#x27;portuguese&#x27;)) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to api_stop_words from function 'set()'. Changing function arguments will change the assigned value.
# - **Linha 46:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 47:** `minhas_stop_words = {&#x27;a&#x27;,&#x27;e&#x27;,&#x27;i&#x27;,&#x27;o&#x27;, &#x27;u&#x27;} `
#   - Tipo: assignment
#   - Explicação: Assignment to minhas_stop_words. Right-hand side is of AST type Set; altering it changes behavior.
# - **Linha 48:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 49:** `stop_words = api_stop_words | minhas_stop_words `
#   - Tipo: assignment
#   - Explicação: Assignment to stop_words. Right-hand side is of AST type BinOp; altering it changes behavior.
# - **Linha 50:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
#
# **Conceitos / técnicas usados nesta célula:**
# - function definitions (modular code)
#
# **Observações gerais:**
# - Parâmetros literais e constantes (ex.: números, strings) geralmente controlam comportamento e são fáceis de ajustar.
# - Chamadas de função podem encapsular lógica complexa — revisar definição da função (se estiver neste notebook) para entender o efeito total.
# - Se a célula importa bibliotecas, essas bibliotecas devem estar instaladas no ambiente para executar o código.
#
# ---

# %% [markdown]
# **(Célula Markdown original)**
#
# # Função para fazer o tratamento de linguagem natural usando spaCy

# %%
def tratamento_pln(texto):
    texto = texto.lower() # 1. Normalização: Colocar o texto em minúsculas
    
    texto = re.sub(r'[^a-zA-Záéíóú\s]', '', texto) # na expressão regular estão as exceções  2. Remoção de números, pontuações e caracteres especiais 
    
    doc = nlp(texto) # 3. Tokenização com spaCy
    
    tokens = [token.text for token in doc]

    clean_tokens = [token.lemma_ for token in doc if token.text not in stop_words and not token.is_punct]  # 4. Remoção de stopwords, remoção de pontuação e Lematização (clean_tokens = tokens lematizados e sem stopwords)
    
    clean_text = ' '.join(clean_tokens) # 5. Juntar tokens lematizados de volta em uma string
    
    return clean_text 

    #return texto 

    # Visualizando as Stop Words 

print("Tamanho do conjunto stop_words:",len(stop_words),"\nStop_words ordenadas: \n",sorted(list(stop_words)))

# %% [markdown]
# ### Célula 8 — Explicação detalhada
#
# **Código original:**
# ```python
# def tratamento_pln(texto):
#     texto = texto.lower() # 1. Normalização: Colocar o texto em minúsculas
#
#     texto = re.sub(r'[^a-zA-Záéíóú\s]', '', texto) # na expressão regular estão as exceções  2. Remoção de números, pontuações e caracteres especiais
#
#     doc = nlp(texto) # 3. Tokenização com spaCy
#
#     tokens = [token.text for token in doc]
#
#     clean_tokens = [token.lemma_ for token in doc if token.text not in stop_words and not token.is_punct]  # 4. Remoção de stopwords, remoção de pontuação e Lematização (clean_tokens = tokens lematizados e sem stopwords)
#
#     clean_text = ' '.join(clean_tokens) # 5. Juntar tokens lematizados de volta em uma string
#
#     return clean_text
#
#     #return texto
#
#     # Visualizando as Stop Words
#
# print("Tamanho do conjunto stop_words:",len(stop_words),"\nStop_words ordenadas: \n",sorted(list(stop_words)))
# ```
#
# **Explicação linha-a-linha:**
#
# - **Linha 1:** `def tratamento_pln(texto):`
#   - Tipo: function_def
#   - Explicação: Function definition: defines a callable block. Parameters in parentheses influence behavior when function is called.
# - **Linha 2:** `    texto = texto.lower() # 1. Normalização: Colocar o texto em minúsculas`
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to texto from function 'texto.lower()'. Changing function arguments will change the assigned value.
# - **Linha 3:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 4:** `    texto = re.sub(r&#x27;[^a-zA-Záéíóú\s]&#x27;, &#x27;&#x27;, texto) # na expressão regular estão as exceções  2. Remoção de números, pontuações e caracteres especiais `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to texto from function 're.sub()'. Changing function arguments will change the assigned value.
# - **Linha 5:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 6:** `    doc = nlp(texto) # 3. Tokenização com spaCy`
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to doc from function 'nlp()'. Changing function arguments will change the assigned value.
# - **Linha 7:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 8:** `    tokens = [token.text for token in doc]`
#   - Tipo: assignment
#   - Explicação: Assignment to tokens. Right-hand side is of AST type ListComp; altering it changes behavior.
# - **Linha 9:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 10:** `    clean_tokens = [token.lemma_ for token in doc if token.text not in stop_words and not token.is_punct]  # 4. Remoção de stopwords, remoção de pontuação e Lematização (clean_tokens = tokens lematizados e sem stopwords)`
#   - Tipo: assignment
#   - Explicação: Assignment to clean_tokens. Right-hand side is of AST type ListComp; altering it changes behavior.
# - **Linha 11:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 12:** `    clean_text = &#x27; &#x27;.join(clean_tokens) # 5. Juntar tokens lematizados de volta em uma string`
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to clean_text from function '' '.join()'. Changing function arguments will change the assigned value.
# - **Linha 13:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 14:** `    return clean_text `
#   - Tipo: return
#   - Explicação: Return statement: returns a value from a function. Changing it changes what callers receive.
# - **Linha 15:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 16:** `    #return texto `
#   - Tipo: comment
#   - Explicação: Comment: return texto — explains intent or documents nearby code.
# - **Linha 17:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 18:** `    # Visualizando as Stop Words `
#   - Tipo: comment
#   - Explicação: Comment: Visualizando as Stop Words — explains intent or documents nearby code.
# - **Linha 19:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 20:** `print(&quot;Tamanho do conjunto stop_words:&quot;,len(stop_words),&quot;\nStop_words ordenadas: \n&quot;,sorted(list(stop_words))) `
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
#
# **Conceitos / técnicas usados nesta célula:**
# - function definitions (modular code)
#
# **Observações gerais:**
# - Parâmetros literais e constantes (ex.: números, strings) geralmente controlam comportamento e são fáceis de ajustar.
# - Chamadas de função podem encapsular lógica complexa — revisar definição da função (se estiver neste notebook) para entender o efeito total.
# - Se a célula importa bibliotecas, essas bibliotecas devem estar instaladas no ambiente para executar o código.
#
# ---

# %% [markdown]
# **(Célula Markdown original)**
#
# # Visualizando as Stop Words

# %%
# Chamada de PLN 

texto_pdf_tratado = tratamento_pln(texto_pdf) 

 

# Tamanho do texto 

print("Tamanho do texto em caracteres:",len(texto_pdf)) 

 

# Arquivo PDF tratado 

print(texto_pdf_tratado) 

 

# Tamanho do texto tratado 

print("Tamanho do texto em caracteres:",len(texto_pdf_tratado))

# %% [markdown]
# ### Célula 10 — Explicação detalhada
#
# **Código original:**
# ```python
#
#
# # Chamada de PLN
#
# texto_pdf_tratado = tratamento_pln(texto_pdf)
#
#
#
# # Tamanho do texto
#
# print("Tamanho do texto em caracteres:",len(texto_pdf))
#
#
#
# # Arquivo PDF tratado
#
# print(texto_pdf_tratado)
#
#
#
# # Tamanho do texto tratado
#
# print("Tamanho do texto em caracteres:",len(texto_pdf_tratado))
# ```
#
# **Explicação linha-a-linha:**
#
# - **Linha 1:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 2:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 3:** `# Chamada de PLN `
#   - Tipo: comment
#   - Explicação: Comment: Chamada de PLN — explains intent or documents nearby code.
# - **Linha 4:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 5:** `texto_pdf_tratado = tratamento_pln(texto_pdf) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to texto_pdf_tratado from function 'tratamento_pln()'. Changing function arguments will change the assigned value.
# - **Linha 6:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 7:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 8:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 9:** `# Tamanho do texto `
#   - Tipo: comment
#   - Explicação: Comment: Tamanho do texto — explains intent or documents nearby code.
# - **Linha 10:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 11:** `print(&quot;Tamanho do texto em caracteres:&quot;,len(texto_pdf)) `
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
# - **Linha 12:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 13:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 14:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 15:** `# Arquivo PDF tratado `
#   - Tipo: comment
#   - Explicação: Comment: Arquivo PDF tratado — explains intent or documents nearby code.
# - **Linha 16:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 17:** `print(texto_pdf_tratado) `
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
# - **Linha 18:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 19:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 20:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 21:** `# Tamanho do texto tratado `
#   - Tipo: comment
#   - Explicação: Comment: Tamanho do texto tratado — explains intent or documents nearby code.
# - **Linha 22:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 23:** `print(&quot;Tamanho do texto em caracteres:&quot;,len(texto_pdf_tratado)) `
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
#
# **Conceitos / técnicas usados nesta célula:**
# - general Python logic (variables, control flow, function calls)
#
# **Observações gerais:**
# - Parâmetros literais e constantes (ex.: números, strings) geralmente controlam comportamento e são fáceis de ajustar.
# - Chamadas de função podem encapsular lógica complexa — revisar definição da função (se estiver neste notebook) para entender o efeito total.
# - Se a célula importa bibliotecas, essas bibliotecas devem estar instaladas no ambiente para executar o código.
#
# ---

# %% [markdown]
# **(Célula Markdown original)**
#
# # Preparação do Texto para BD Vetorial

# %%
# Dividindo os documentos em Chunks 

text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=30) 

chunks = text_splitter.split_text(texto_pdf_tratado) 

print(chunks, len(chunks)) 

 

# Carregar o modelo de Embeddings bem como gerar os Embeddings 

model = SentenceTransformer('all-MiniLM-L6-v2') 

embeddings = model.encode(chunks) 

 

# Gerando IDs automaticamente 

uids = [f"doc_{i}" for i in range(len(chunks))]

# %% [markdown]
# ### Célula 12 — Explicação detalhada
#
# **Código original:**
# ```python
# # Dividindo os documentos em Chunks
#
# text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=30)
#
# chunks = text_splitter.split_text(texto_pdf_tratado)
#
# print(chunks, len(chunks))
#
#
#
# # Carregar o modelo de Embeddings bem como gerar os Embeddings
#
# model = SentenceTransformer('all-MiniLM-L6-v2')
#
# embeddings = model.encode(chunks)
#
#
#
# # Gerando IDs automaticamente
#
# uids = [f"doc_{i}" for i in range(len(chunks))]
# ```
#
# **Explicação linha-a-linha:**
#
# - **Linha 1:** `# Dividindo os documentos em Chunks `
#   - Tipo: comment
#   - Explicação: Comment: Dividindo os documentos em Chunks — explains intent or documents nearby code.
# - **Linha 2:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 3:** `text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=30) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to text_splitter from function 'RecursiveCharacterTextSplitter()'. Changing function arguments will change the assigned value.
# - **Linha 4:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 5:** `chunks = text_splitter.split_text(texto_pdf_tratado) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to chunks from function 'text_splitter.split_text()'. Changing function arguments will change the assigned value.
# - **Linha 6:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 7:** `print(chunks, len(chunks)) `
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
# - **Linha 8:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 9:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 10:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 11:** `# Carregar o modelo de Embeddings bem como gerar os Embeddings `
#   - Tipo: comment
#   - Explicação: Comment: Carregar o modelo de Embeddings bem como gerar os Embeddings — explains intent or documents nearby code.
# - **Linha 12:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 13:** `model = SentenceTransformer(&#x27;all-MiniLM-L6-v2&#x27;) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to model from function 'SentenceTransformer()'. Changing function arguments will change the assigned value.
# - **Linha 14:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 15:** `embeddings = model.encode(chunks) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to embeddings from function 'model.encode()'. Changing function arguments will change the assigned value.
# - **Linha 16:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 17:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 18:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 19:** `# Gerando IDs automaticamente `
#   - Tipo: comment
#   - Explicação: Comment: Gerando IDs automaticamente — explains intent or documents nearby code.
# - **Linha 20:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 21:** `uids = [f&quot;doc_{i}&quot; for i in range(len(chunks))] `
#   - Tipo: assignment
#   - Explicação: Assignment to uids. Right-hand side is of AST type ListComp; altering it changes behavior.
#
# **Conceitos / técnicas usados nesta célula:**
# - general Python logic (variables, control flow, function calls)
#
# **Observações gerais:**
# - Parâmetros literais e constantes (ex.: números, strings) geralmente controlam comportamento e são fáceis de ajustar.
# - Chamadas de função podem encapsular lógica complexa — revisar definição da função (se estiver neste notebook) para entender o efeito total.
# - Se a célula importa bibliotecas, essas bibliotecas devem estar instaladas no ambiente para executar o código.
#
# ---

# %% [markdown]
# **(Célula Markdown original)**
#
# ## Aplicação do ChromaDB

# %%
# Criar o banco de dados 

client = chromadb.Client() 

collection = client.create_collection(name="machlrn") 

 

#client.delete_collection("machlrn") 

 

# Adicionar os documentos ao banco de dados 

collection.add(documents=chunks, embeddings=embeddings, ids=uids) 

 

# Realizar a busca usando collection.query 

query_embedding = model.encode(["Como ensinar computadores a reconhecer padrões?"]) 

# query_embedding = model.encode(["Explique aprendizado não supervisionado"]) 

# query_embedding = model.encode(["Quais redes neurais são usadas em NLP?"]) 

 

results = collection.query(query_embeddings=query_embedding, n_results=1) 

print(results) 

 

# Imprimir os resultados 

# Fazendo a varredura sobre os campos 'ids', 'distances' e 'documents' 

for i in range(len(results['ids'][0])):
    doc_id = results['ids'][0][i]
    
    distance = results['distances'][0][i]
    
    document = results['documents'][0][i] 

    print(f"ID: {doc_id}")
    
    print(f"Distância: {distance}")
    
    print(f"Documento: {document}")
    
    print("-" * 40)

# %% [markdown]
# ### Célula 14 — Explicação detalhada
#
# **Código original:**
# ```python
# # Criar o banco de dados
#
# client = chromadb.Client()
#
# collection = client.create_collection(name="machlrn")
#
#
#
# #client.delete_collection("machlrn")
#
#
#
# # Adicionar os documentos ao banco de dados
#
# collection.add(documents=chunks, embeddings=embeddings, ids=uids)
#
#
#
# # Realizar a busca usando collection.query
#
# query_embedding = model.encode(["Como ensinar computadores a reconhecer padrões?"])
#
# # query_embedding = model.encode(["Explique aprendizado não supervisionado"])
#
# # query_embedding = model.encode(["Quais redes neurais são usadas em NLP?"])
#
#
#
# results = collection.query(query_embeddings=query_embedding, n_results=1)
#
# print(results)
#
#
#
# # Imprimir os resultados
#
# # Fazendo a varredura sobre os campos 'ids', 'distances' e 'documents'
#
# for i in range(len(results['ids'][0])):
#     doc_id = results['ids'][0][i]
#
#     distance = results['distances'][0][i]
#
#     document = results['documents'][0][i]
#
#     print(f"ID: {doc_id}")
#
#     print(f"Distância: {distance}")
#
#     print(f"Documento: {document}")
#
#     print("-" * 40)
# ```
#
# **Explicação linha-a-linha:**
#
# - **Linha 1:** `# Criar o banco de dados `
#   - Tipo: comment
#   - Explicação: Comment: Criar o banco de dados — explains intent or documents nearby code.
# - **Linha 2:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 3:** `client = chromadb.Client() `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to client from function 'chromadb.Client()'. Changing function arguments will change the assigned value.
# - **Linha 4:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 5:** `collection = client.create_collection(name=&quot;machlrn&quot;) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to collection from function 'client.create_collection()'. Changing function arguments will change the assigned value.
# - **Linha 6:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 7:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 8:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 9:** `#client.delete_collection(&quot;machlrn&quot;) `
#   - Tipo: comment
#   - Explicação: Comment: client.delete_collection("machlrn") — explains intent or documents nearby code.
# - **Linha 10:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 11:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 12:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 13:** `# Adicionar os documentos ao banco de dados `
#   - Tipo: comment
#   - Explicação: Comment: Adicionar os documentos ao banco de dados — explains intent or documents nearby code.
# - **Linha 14:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 15:** `collection.add(documents=chunks, embeddings=embeddings, ids=uids) `
#   - Tipo: function_call
#   - Explicação: Function call: collection.add(...). Arguments determine what the function does.
# - **Linha 16:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 17:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 18:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 19:** `# Realizar a busca usando collection.query `
#   - Tipo: comment
#   - Explicação: Comment: Realizar a busca usando collection.query — explains intent or documents nearby code.
# - **Linha 20:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 21:** `query_embedding = model.encode([&quot;Como ensinar computadores a reconhecer padrões?&quot;]) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to query_embedding from function 'model.encode()'. Changing function arguments will change the assigned value.
# - **Linha 22:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 23:** `# query_embedding = model.encode([&quot;Explique aprendizado não supervisionado&quot;]) `
#   - Tipo: comment
#   - Explicação: Comment: query_embedding = model.encode(["Explique aprendizado não supervisionado"]) — explains intent or documents nearby code.
# - **Linha 24:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 25:** `# query_embedding = model.encode([&quot;Quais redes neurais são usadas em NLP?&quot;]) `
#   - Tipo: comment
#   - Explicação: Comment: query_embedding = model.encode(["Quais redes neurais são usadas em NLP?"]) — explains intent or documents nearby code.
# - **Linha 26:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 27:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 28:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 29:** `results = collection.query(query_embeddings=query_embedding, n_results=1) `
#   - Tipo: assignment_call
#   - Explicação: Assigns result of call to results from function 'collection.query()'. Changing function arguments will change the assigned value.
# - **Linha 30:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 31:** `print(results) `
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
# - **Linha 32:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 33:** ` `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 34:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 35:** `# Imprimir os resultados `
#   - Tipo: comment
#   - Explicação: Comment: Imprimir os resultados — explains intent or documents nearby code.
# - **Linha 36:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 37:** `# Fazendo a varredura sobre os campos &#x27;ids&#x27;, &#x27;distances&#x27; e &#x27;documents&#x27; `
#   - Tipo: comment
#   - Explicação: Comment: Fazendo a varredura sobre os campos 'ids', 'distances' e 'documents' — explains intent or documents nearby code.
# - **Linha 38:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 39:** `for i in range(len(results[&#x27;ids&#x27;][0])):`
#   - Tipo: unknown
#   - Explicação: Could not statically parse this line; it's: for i in range(len(results['ids'][0])):
# - **Linha 40:** `    doc_id = results[&#x27;ids&#x27;][0][i]`
#   - Tipo: assignment
#   - Explicação: Assignment to doc_id. Right-hand side is of AST type Subscript; altering it changes behavior.
# - **Linha 41:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 42:** `    distance = results[&#x27;distances&#x27;][0][i]`
#   - Tipo: assignment
#   - Explicação: Assignment to distance. Right-hand side is of AST type Subscript; altering it changes behavior.
# - **Linha 43:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 44:** `    document = results[&#x27;documents&#x27;][0][i] `
#   - Tipo: assignment
#   - Explicação: Assignment to document. Right-hand side is of AST type Subscript; altering it changes behavior.
# - **Linha 45:** ``
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 46:** `    print(f&quot;ID: {doc_id}&quot;)`
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
# - **Linha 47:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 48:** `    print(f&quot;Distância: {distance}&quot;)`
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
# - **Linha 49:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 50:** `    print(f&quot;Documento: {document}&quot;)`
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
# - **Linha 51:** `    `
#   - Tipo: blank
#   - Explicação: Blank line (no code).
# - **Linha 52:** `    print(&quot;-&quot; * 40) `
#   - Tipo: function_call
#   - Explicação: Function call: print(...). Arguments determine what the function does.
#
# **Conceitos / técnicas usados nesta célula:**
# - general Python logic (variables, control flow, function calls)
#
# **Observações gerais:**
# - Parâmetros literais e constantes (ex.: números, strings) geralmente controlam comportamento e são fáceis de ajustar.
# - Chamadas de função podem encapsular lógica complexa — revisar definição da função (se estiver neste notebook) para entender o efeito total.
# - Se a célula importa bibliotecas, essas bibliotecas devem estar instaladas no ambiente para executar o código.
#
# ---
